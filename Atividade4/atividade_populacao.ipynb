# %% [markdown]
# # População brasileira: 2010 e 2022
#
# Agregações por estado e município, ordenadas pela variação absoluta da população entre 2010 e 2022.

# %%
import pandas as pd

ARQUIVO_ENTRADA = 'CD2022_Populacao_2010_Compatibilizada_20231222.xlsx'

df = pd.read_excel(ARQUIVO_ENTRADA, sheet_name=0, skiprows=2)
df = df[df['COD. UF'].notna()].copy()
df.columns = ['IGNORAR', 'UF', 'COD_UF', 'COD_MUNIC', 'MUNICIPIO', 'POP_2010_SINOPSE', 'POP_2010_COMPATIBILIZADA', 'POP_2022']

col_2010 = 'POP_2010_COMPATIBILIZADA'
col_2022 = 'POP_2022'
df['Crescimento 2010-2022'] = df[col_2022] - df[col_2010]

df.head()
# Out:
#    IGNORAR  UF  COD_UF  COD_MUNIC              MUNICIPIO  POP_2010_SINOPSE  \
# 0      NaN  RO    11.0       15.0  Alta Floresta D'Oeste           24392.0
# 1      NaN  RO    11.0       23.0              Ariquemes           90353.0
# 2      NaN  RO    11.0       31.0                 Cabixi            6313.0
# 3      NaN  RO    11.0       49.0                 Cacoal           78574.0
# 4      NaN  RO    11.0       56.0             Cerejeiras           17029.0
#
#    POP_2010_COMPATIBILIZADA  POP_2022  Crescimento 2010-2022
# 0                   24392.0   21494.0                -2898.0
# 1                   90353.0   96833.0                 6480.0
# 2                    6313.0    5351.0                 -962.0
# 3                   78574.0   86887.0                 8313.0
# 4                   17029.0   15890.0                -1139.0

# %%
populacao_estado = (
    df.groupby('UF')[[col_2010, col_2022, 'Crescimento 2010-2022']]
      .sum()
      .reset_index()
      .sort_values('Crescimento 2010-2022', ascending=False)
)

populacao_estado.to_csv('populacao_por_estado.csv', sep=';', index=False, encoding='utf-8-sig')
populacao_estado
# Out:
#     UF  POP_2010_COMPATIBILIZADA    POP_2022  Crescimento 2010-2022
# 25  SP                41262199.0  44411238.0              3149039.0
# 23  SC                 6248436.0   7610361.0              1361925.0
# 8   GO                 6001789.0   7056495.0              1054706.0
# 17  PR                10444526.0  11444380.0               999854.0
# 10  MG                19597330.0  20539989.0               942659.0
# 12  MT                 3035122.0   3658649.0               623527.0
# 13  PA                 7581051.0   8120131.0               539080.0
# 2   AM                 3483985.0   3941613.0               457628.0
# 5   CE                 8451644.0   8794957.0               343313.0
# 7   ES                 3514952.0   3833712.0               318760.0
# 11  MS                 2449024.0   2757013.0               307989.0
# 15  PE                 8796055.0   9058931.0               262876.0
# 6   DF                 2572159.0   2817381.0               245222.0
# ...

# %%
populacao_municipio = (
    df[['UF', 'COD_UF', 'COD_MUNIC', 'MUNICIPIO', col_2010, col_2022, 'Crescimento 2010-2022']]
      .sort_values('Crescimento 2010-2022', ascending=False)
)

populacao_municipio.to_csv('populacao_por_municipio.csv', sep=';', index=False, encoding='utf-8-sig')
populacao_municipio.head()
# Out:
#       UF  COD_UF  COD_MUNIC  MUNICIPIO  POP_2010_COMPATIBILIZADA    POP_2022  \
# 111   AM    13.0     2603.0     Manaus                 1802014.0   2063689.0
# 5569  DF    53.0      108.0   Brasília                 2572159.0   2817381.0
# 3829  SP    35.0    50308.0  São Paulo                11253503.0  11451999.0
# 3848  SP    35.0    52205.0   Sorocaba                  586816.0    723682.0
# 5417  GO    52.0     8707.0    Goiânia                 1301912.0   1437366.0
#
#       Crescimento 2010-2022
# 111                261675.0
# 5569               245222.0
# 3829               198496.0
# 3848               136866.0
# 5417               135454.0
